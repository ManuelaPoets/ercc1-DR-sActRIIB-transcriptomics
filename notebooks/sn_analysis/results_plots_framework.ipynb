# %%
# Step 1: Mount Drive & Setup (runs in Colab)
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Import framework
import sys
sys.path.append('/content/drive/MyDrive/Promotion/Thesis/Thesis_writing/Results/scripts')
from thesis_plotting_utils import *

# Step 3: Create figures!
fig, ax = create_figure(width=7, height=5)
plot_volcano(ax, df, ...)
save_figure(fig, 'my_figure')
plt.show()  # Shows in Colab!
